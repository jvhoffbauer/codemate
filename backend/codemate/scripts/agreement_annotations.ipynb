# %%
data = """JV,Toni,Lukas
1 - Helpful,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
1 - Helpful,2 - Somewhat Helpful,1 - Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,3 - Not Relevant
1 - Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,2 - Somewhat Helpful,3 - Not Relevant
2 - Somewhat Helpful,2 - Somewhat Helpful,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
3 - Not Relevant,2 - Somewhat Helpful,2 - Somewhat Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
3 - Not Relevant,2 - Somewhat Helpful,2 - Somewhat Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,1 - Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
3 - Not Relevant,2 - Somewhat Helpful,2 - Somewhat Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
3 - Not Relevant,2 - Somewhat Helpful,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,2 - Somewhat Helpful,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,2 - Somewhat Helpful
1 - Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,2 - Somewhat Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
3 - Not Relevant,1 - Helpful,2 - Somewhat Helpful
3 - Not Relevant,1 - Helpful,2 - Somewhat Helpful
3 - Not Relevant,1 - Helpful,2 - Somewhat Helpful
3 - Not Relevant,1 - Helpful,2 - Somewhat Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
3 - Not Relevant,1 - Helpful,2 - Somewhat Helpful
3 - Not Relevant,1 - Helpful,2 - Somewhat Helpful
3 - Not Relevant,1 - Helpful,2 - Somewhat Helpful
1 - Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,1 - Helpful
1 - Helpful,2 - Somewhat Helpful,1 - Helpful
1 - Helpful,3 - Not Relevant,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,1 - Helpful
3 - Not Relevant,3 - Not Relevant,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,1 - Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,2 - Somewhat Helpful,1 - Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
1 - Helpful,3 - Not Relevant,1 - Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
1 - Helpful,3 - Not Relevant,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
3 - Not Relevant,2 - Somewhat Helpful,3 - Not Relevant
1 - Helpful,1 - Helpful,1 - Helpful
3 - Not Relevant,2 - Somewhat Helpful,3 - Not Relevant
3 - Not Relevant,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,2 - Somewhat Helpful,1 - Helpful
3 - Not Relevant,3 - Not Relevant,2 - Somewhat Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,2 - Somewhat Helpful,2 - Somewhat Helpful
2 - Somewhat Helpful,2 - Somewhat Helpful,2 - Somewhat Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,2 - Somewhat Helpful,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
2 - Somewhat Helpful,1 - Helpful,1 - Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,2 - Somewhat Helpful,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
1 - Helpful,3 - Not Relevant,1 - Helpful
2 - Somewhat Helpful,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
2 - Somewhat Helpful,2 - Somewhat Helpful,3 - Not Relevant
2 - Somewhat Helpful,2 - Somewhat Helpful,3 - Not Relevant
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,2 - Somewhat Helpful,1 - Helpful
1 - Helpful,2 - Somewhat Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,3 - Not Relevant,3 - Not Relevant
3 - Not Relevant,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful
1 - Helpful,1 - Helpful,1 - Helpful"""

# %%
import pandas as pd
from io import StringIO
from collections import Counter

df = pd.read_csv(StringIO(data), sep=',', header=None, skiprows=1)
print(Counter(df[0].to_list() + df[1].to_list() + df[2].to_list()))
df = df.applymap({"1 - Helpful": 0, "2 - Somewhat Helpful": 1, "3 - Not Relevant": 2}.get)
print("DF:")
df
# Out:
# Counter({'3 - Not Relevant': 242, '1 - Helpful': 182, '2 - Somewhat Helpful': 116})
# DF:
# /tmp/ipykernel_1915445/4038931378.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap({"1 - Helpful": 0, "2 - Somewhat Helpful": 1, "3 - Not Relevant": 2}.get)
#      0  1  2
# 0    0  2  2
# 1    2  2  2
# 2    1  2  2
# 3    2  2  2
# 4    2  2  1
# ..  .. .. ..
# 175  0  0  0
# 176  0  0  0
# 177  0  0  0
# 178  0  0  0
# 179  0  0  0
#
# [180 rows x 3 columns]

# %%
from statsmodels.stats.inter_rater import fleiss_kappa, aggregate_raters

# %%
r = aggregate_raters(df.values, n_cat=3)
r
# Out:
# (array([[1, 0, 2],
#         [0, 0, 3],
#         [0, 1, 2],
#         [0, 0, 3],
#         [0, 1, 2],
#         [0, 1, 2],
#         [0, 1, 2],
#         [0, 0, 3],
#         [0, 0, 3],
#         [2, 1, 0],
#         [1, 2, 0],
#         [3, 0, 0],
#         [0, 1, 2],
#         [3, 0, 0],
#         [0, 1, 2],
#         [0, 1, 2],
#         [0, 3, 0],
#         [0, 0, 3],
#         [1, 2, 0],
#         [1, 2, 0],
#         [0, 2, 1],
#         [1, 2, 0],
#         [0, 0, 3],
#         [1, 2, 0],
#         [0, 2, 1],
#         [2, 1, 0],
#         [1, 1, 1],
#         [0, 0, 3],
#         [2, 1, 0],
#         [0, 2, 1],
#         [1, 2, 0],
#         [0, 2, 1],
#         [0, 1, 2],
#         [0, 2, 1],
#         [0, 0, 3],
#         [2, 1, 0],
#         [0, 0, 3],
#         [0, 0, 3],
#         [0, 1, 2],
#         [0, 1, 2],
#         [0, 1, 2],
#         [0, 0, 3],
#         [0, 0, 3],
#         [0, 0, 3],
#         [0, 0, 3],
#         [0, 0, 3],
#         [0, 0, 3],
# ...

# %%
fleiss_kappa(r[0])
# Out:
# 0.4236710001287166
